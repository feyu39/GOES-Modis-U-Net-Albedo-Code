# %%
history = %run Albedo-U-Net.py
# Out:
# All invalid dates
# 2021-09-18
# 2021-12-11
# 2021-12-20
# 2021-12-28
# 2021-12-29
# 2021-12-30
# 2021-12-31
# 2022-01-01
# 2022-01-03
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-03-05
# 2022-03-18
# 2022-04-08
# 2022-05-02
# 2022-05-19
# 2022-05-24
# All invalid dates
# 2021-09-18
# 2021-12-11
# 2021-12-20
# 2021-12-28
# 2021-12-29
# 2021-12-30
# 2021-12-31
# 2022-01-01
# 2022-01-03
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-03-05
# 2022-03-18
# 2022-04-08
# 2022-05-02
# 2022-05-19
# 2022-05-24
# GOES Training data shape: (348, 24, 24, 1)
# MODIS Training data shape: (348, 24, 24, 1)
# All invalid dates
# 2022-09-13
# 2022-11-16
# 2022-11-17
# 2022-12-16
# 2022-12-18
# 2022-12-19
# 2022-12-28
# 2022-12-29
# 2022-12-30
# 2022-12-31
# All invalid dates
# 2022-09-13
# 2022-11-16
# 2022-11-17
# 2022-12-16
# 2022-12-18
# 2022-12-19
# 2022-12-28
# 2022-12-29
# 2022-12-30
# 2022-12-31
# GOES Validation data shape: (111, 24, 24, 1)
# MODIS Validation data shape: (111, 24, 24, 1)
# All invalid dates
# 2021-09-18
# 2021-12-11
# 2021-12-20
# 2021-12-28
# 2021-12-29
# 2021-12-30
# 2021-12-31
# 2022-01-01
# 2022-01-03
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-03-05
# 2022-03-18
# 2022-04-08
# 2022-05-02
# 2022-05-19
# 2022-05-24
# 2022-09-13
# 2022-11-16
# 2022-11-17
# 2022-12-16
# 2022-12-18
# 2022-12-19
# 2022-12-28
# 2022-12-29
# 2022-12-30
# 2022-12-31
# 2023-01-01
# 2023-01-02
# 2023-01-03
# 2023-01-04
# 2023-01-05
# 2023-01-06
# 2023-01-07
# 2023-01-08
# 2023-01-09
# 2023-01-10
# 2023-01-11
# 2023-01-13
# 2023-02-26
# 2023-03-14
# 2023-05-11
# 2023-06-01
# All invalid dates
# 2021-09-18
# 2021-12-11
# 2021-12-20
# 2021-12-28
# 2021-12-29
# 2021-12-30
# 2021-12-31
# 2022-01-01
# 2022-01-03
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-03-05
# 2022-03-18
# 2022-04-08
# 2022-05-02
# 2022-05-19
# 2022-05-24
# 2022-09-13
# 2022-11-16
# 2022-11-17
# 2022-12-16
# 2022-12-18
# 2022-12-19
# 2022-12-28
# 2022-12-29
# 2022-12-30
# 2022-12-31
# 2023-01-01
# 2023-01-02
# 2023-01-03
# 2023-01-04
# 2023-01-05
# 2023-01-06
# 2023-01-07
# 2023-01-08
# 2023-01-09
# 2023-01-10
# 2023-01-11
# 2023-01-13
# 2023-02-26
# 2023-03-14
# 2023-05-11
# 2023-06-01
# GOES Test data shape: (609, 24, 24, 1)
# Done pre-processing data
# Epoch 1/500
#
# Epoch 1: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 7s - 645ms/step - loss: 0.0262 - root_mean_squared_error: 0.1620 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1286 - learning_rate: 0.0010
# Epoch 2/500
#
# Epoch 2: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 42ms/step - loss: 0.0100 - root_mean_squared_error: 0.1002 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195 - learning_rate: 0.0010
# Epoch 3/500
#
# Epoch 3: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 41ms/step - loss: 0.0098 - root_mean_squared_error: 0.0989 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219 - learning_rate: 0.0010
# Epoch 4/500
#
# Epoch 4: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 41ms/step - loss: 0.0094 - root_mean_squared_error: 0.0972 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212 - learning_rate: 0.0010
# Epoch 5/500
#
# Epoch 5: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 39ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1111 - learning_rate: 0.0010
# Epoch 6/500
#
# Epoch 6: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 46ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165 - learning_rate: 0.0010
# Epoch 7/500
#
# Epoch 7: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 47ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088 - learning_rate: 0.0010
# Epoch 8/500
#
# Epoch 8: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 40ms/step - loss: 0.0074 - root_mean_squared_error: 0.0860 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109 - learning_rate: 0.0010
# Epoch 9/500
#
# Epoch 9: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 37ms/step - loss: 0.0069 - root_mean_squared_error: 0.0829 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104 - learning_rate: 0.0010
# Epoch 10/500
#
# Epoch 10: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 40ms/step - loss: 0.0068 - root_mean_squared_error: 0.0828 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096 - learning_rate: 0.0010
# Epoch 11/500
#
# Epoch 11: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 40ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1089 - learning_rate: 0.0010
# Epoch 12/500
#
# Epoch 12: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 39ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130 - learning_rate: 0.0010
# Epoch 13/500
#
# Epoch 13: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 41ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101 - learning_rate: 0.0010
# Epoch 14/500
#
# Epoch 14: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 38ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110 - learning_rate: 0.0010
# Epoch 15/500
#
# Epoch 15: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 38ms/step - loss: 0.0063 - root_mean_squared_error: 0.0797 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098 - learning_rate: 0.0010
# Epoch 16/500
#
# Epoch 16: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 37ms/step - loss: 0.0065 - root_mean_squared_error: 0.0808 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157 - learning_rate: 0.0010
# Epoch 17/500
#
# Epoch 17: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 54ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078 - learning_rate: 0.0010
# Epoch 18/500
#
# Epoch 18: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 39ms/step - loss: 0.0067 - root_mean_squared_error: 0.0815 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104 - learning_rate: 0.0010
# Epoch 19/500
#
# Epoch 19: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 41ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099 - learning_rate: 0.0010
# Epoch 20/500
#
# Epoch 20: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 39ms/step - loss: 0.0065 - root_mean_squared_error: 0.0809 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106 - learning_rate: 0.0010
# Epoch 21/500
#
# Epoch 21: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 78ms/step - loss: 0.0070 - root_mean_squared_error: 0.0836 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123 - learning_rate: 0.0010
# Epoch 22/500
#
# Epoch 22: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 37ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110 - learning_rate: 0.0010
# Epoch 23/500
#
# Epoch 23: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 40ms/step - loss: 0.0064 - root_mean_squared_error: 0.0799 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217 - learning_rate: 0.0010
# Epoch 24/500
#
# Epoch 24: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 60ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1223 - learning_rate: 0.0010
# Epoch 25/500
#
# Epoch 25: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 61ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133 - learning_rate: 0.0010
# Epoch 26/500
#
# Epoch 26: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 39ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114 - learning_rate: 0.0010
# Epoch 27/500
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 27: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 42ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1152 - learning_rate: 0.0010
# Epoch 28/500
#
# Epoch 28: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 41ms/step - loss: 0.0059 - root_mean_squared_error: 0.0767 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117 - learning_rate: 5.0000e-04
# Epoch 29/500
#
# Epoch 29: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 60ms/step - loss: 0.0056 - root_mean_squared_error: 0.0749 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1166 - learning_rate: 5.0000e-04
# Epoch 30/500
#
# Epoch 30: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 41ms/step - loss: 0.0053 - root_mean_squared_error: 0.0727 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195 - learning_rate: 5.0000e-04
# Epoch 31/500
#
# Epoch 31: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 0s - 39ms/step - loss: 0.0052 - root_mean_squared_error: 0.0720 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148 - learning_rate: 5.0000e-04
# Epoch 32/500
#
# Epoch 32: saving model to /global/cfs/cdirs/m3779/felix/UNet/Results/training/cp.weights.h5
# 11/11 - 1s - 59ms/step - loss: 0.0051 - root_mean_squared_error: 0.0718 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169 - learning_rate: 5.0000e-04
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0074 - root_mean_squared_error: 0.0843
# Test Loss: 0.008290652185678482
# Test Root Mean Squared Error: 0.09105301648378372
# Predicted array shape: (609, 24, 24)
# Final Array shape f(609, 21, 19)
# Time for U-Net to run: 23.874163389205933 seconds

# %% [markdown]
# ## Plot training and validation loss

# %%
import json
import matplotlib.pyplot as plt

# %%
TF_HISTORY_PATH = "/global/cfs/cdirs/m3779/felix/UNet/Results/training/history.json"

# %%
with open(TF_HISTORY_PATH, 'r') as file:
    history_dict = json.load(file)
    
training_loss = history_dict['loss']
validation_loss = history_dict['val_loss']

plt.figure(figsize=(10, 5))
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
